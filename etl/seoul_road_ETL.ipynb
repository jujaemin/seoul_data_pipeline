# %% [markdown]
# # 0. 필요 패키지, 변수 정의

# %%
import requests
import json
import datetime

# %% [markdown]
# # 1. extract 함수 정의

# %%
def extract(api_key):
    base_url = "https://t-data.seoul.go.kr/apig/apiman-gateway/tapi/TopisIccStTimesRoadDivTrfLivingStats/1.0"
    startRow = "1"
    stndDt = "20240213" # 데이터 자체는 1시간 단위지만, API 데이터 업데이트 주기가 하루에 1번 입니다. 즉, 하루 치 데이터가 모여서 한 번에 들어옵니다.
    rowCnt = "120" # 도심생활권, 동남생활권, 동북생활권, 서남생활권, 서북생활권 5개 권역이 1시간마다 1번 기록됩니다. 5개 권역 x 24시간 = 120개

    url =   base_url + \
            "?startRow=" + startRow + \
            "&apikey=" + api_key + \
            "&stndDt=" + stndDt + \
            "&rowCnt=" + rowCnt

    response = requests.get(url, verify=False)
    serialized_records = json.dumps(response.json()) # Serialize

    return serialized_records

# %% [markdown]
# # 2. transform 함수 정의

# %%
def transform(serialized_records):
    deserialized_data = json.loads(serialized_records) # Deserialize

    pass # TO DO

# %% [markdown]
# # 3. extract, transform 함수 실행

# %%
api_key = "3434c304-aaff-4963-a4cd-86821380b26c"

serialized_records = extract(api_key)
print(serialized_records)
# Out:
# C:\Users\cbs02\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 't-data.seoul.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# [{"stndDt": "20240213", "roadDivCd": "21", "roadDivNm": "\ub3c4\uc2ec\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "29.08", "dayCd": "3", "dayGrpCd": "01", "timeCd": "01", "timeNm": "~1\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "22", "roadDivNm": "\ub3d9\ub0a8\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "30.57", "dayCd": "3", "dayGrpCd": "01", "timeCd": "01", "timeNm": "~1\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "23", "roadDivNm": "\ub3d9\ubd81\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "28.31", "dayCd": "3", "dayGrpCd": "01", "timeCd": "01", "timeNm": "~1\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "24", "roadDivNm": "\uc11c\ub0a8\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "30.13", "dayCd": "3", "dayGrpCd": "01", "timeCd": "01", "timeNm": "~1\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "25", "roadDivNm": "\uc11c\ubd81\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "28.04", "dayCd": "3", "dayGrpCd": "01", "timeCd": "01", "timeNm": "~1\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "21", "roadDivNm": "\ub3c4\uc2ec\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "29.81", "dayCd": "3", "dayGrpCd": "01", "timeCd": "02", "timeNm": "~2\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "22", "roadDivNm": "\ub3d9\ub0a8\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "31.43", "dayCd": "3", "dayGrpCd": "01", "timeCd": "02", "timeNm": "~2\uc2dc"}, {"stndDt": "20240213", "roadDivCd": "23", "roadDivNm": "\ub3d9\ubd81\uc0dd\ud65c\uad8c", "timeGrpNm": "N", "avgSpd": "28.75", "